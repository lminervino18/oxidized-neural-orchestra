# %% [markdown]
# ## 1. Setup & MNIST Download
#
# Downloads the raw MNIST files, normalizes pixel values to `[0, 1]`, encodes labels as one-hot vectors, and writes two packed `f32` binary files (`data/mnist_train.bin`, `data/mnist_test.bin`) in the format expected by O.N.O (`x_size=784`, `y_size=10`, 794 floats per row).

# %%
import os, struct, gzip, shutil, urllib.request, subprocess, time
import numpy as np

NWORKERS = 3
NSERVERS = 2
BASE_WORKER_PORT = 50000
BASE_SERVER_PORT = 40000
WORKER_ADDRS = [f"worker-{i}:{BASE_WORKER_PORT + i}" for i in range(NWORKERS)]
SERVER_ADDRS = [f"server-{i}:{BASE_SERVER_PORT + i}" for i in range(NSERVERS)]

URLS = {
    "train_images": "https://storage.googleapis.com/cvdf-datasets/mnist/train-images-idx3-ubyte.gz",
    "train_labels": "https://storage.googleapis.com/cvdf-datasets/mnist/train-labels-idx1-ubyte.gz",
    "test_images":  "https://storage.googleapis.com/cvdf-datasets/mnist/t10k-images-idx3-ubyte.gz",
    "test_labels":  "https://storage.googleapis.com/cvdf-datasets/mnist/t10k-labels-idx1-ubyte.gz",
}
RAW_DIR  = "data/mnist_raw"
TRAIN_BIN = "data/mnist_train.bin"
TEST_BIN  = "data/mnist_test.bin"
SAFETENSORS_PATH = "data/mnist_model.safetensors"
X_SIZE, Y_SIZE, ROW_SIZE = 784, 10, 794

def download(name, url):
    os.makedirs(RAW_DIR, exist_ok=True)
    gz, raw = os.path.join(RAW_DIR, name + ".gz"), os.path.join(RAW_DIR, name)
    if os.path.exists(raw):
        print(f"  already exists: {raw}"); return raw
    print(f"  downloading {name}...")
    urllib.request.urlretrieve(url, gz)
    with gzip.open(gz, "rb") as fi, open(raw, "wb") as fo:
        shutil.copyfileobj(fi, fo)
    os.remove(gz)
    return raw

def read_images(path):
    with open(path, "rb") as f:
        _, n, rows, cols = struct.unpack(">IIII", f.read(16))
        raw = f.read(n * rows * cols)
    ppi = rows * cols
    return [[b / 255.0 for b in raw[i*ppi:(i+1)*ppi]] for i in range(n)]

def read_labels(path):
    with open(path, "rb") as f:
        _, n = struct.unpack(">II", f.read(8))
        return list(f.read(n))

def write_bin(images, labels, out_path):
    os.makedirs(os.path.dirname(out_path), exist_ok=True)
    with open(out_path, "wb") as f:
        for img, lbl in zip(images, labels):
            oh = [0.0] * Y_SIZE; oh[lbl] = 1.0
            f.write(struct.pack(f"{ROW_SIZE}f", *(img + oh)))
    print(f"  wrote {len(images)} samples → {out_path} ({os.path.getsize(out_path)/1024/1024:.1f} MB)")

for name, url in URLS.items():
    download(name, url)

if not os.path.exists(TRAIN_BIN):
    write_bin(read_images(os.path.join(RAW_DIR,"train_images")), read_labels(os.path.join(RAW_DIR,"train_labels")), TRAIN_BIN)
else:
    print(f"training set already exists: {TRAIN_BIN}")

if not os.path.exists(TEST_BIN):
    write_bin(read_images(os.path.join(RAW_DIR,"test_images")), read_labels(os.path.join(RAW_DIR,"test_labels")), TEST_BIN)
else:
    print(f"test set already exists: {TEST_BIN}")
# Out:
#   already exists: data/mnist_raw/train_images
#   already exists: data/mnist_raw/train_labels
#   already exists: data/mnist_raw/test_images
#   already exists: data/mnist_raw/test_labels
# training set already exists: data/mnist_train.bin
# test set already exists: data/mnist_test.bin

# %% [markdown]
# ## 2. Start Workers & Servers
#
# Brings up `NSERVERS` parameter servers and `NWORKERS` workers as Docker containers. Each container logs via Docker. A short sleep is added after startup to ensure all entities are listening before the orchestrator connects.

# %%
import getpass

DOCKER_DIR = os.path.abspath("../../docker")
COMPOSE_FILE = os.path.abspath("../../compose.yaml")

sudo_password = getpass.getpass("sudo password: ")

# Generate compose file
subprocess.run(
    ["python3", f"{DOCKER_DIR}/gen_compose.py"],
    env={
        **os.environ,
        "WORKERS": str(NWORKERS),
        "SERVERS": str(NSERVERS),
        "RELEASE": "true",
    },
    check=True,
)

# Fill /etc/hosts with worker/server hostname translations
subprocess.run(
    ["sudo", "-S", "-E", "python3", f"{DOCKER_DIR}/fill_hosts.py"],
    input=sudo_password + "\n",
    text=True,
    env={**os.environ, "WORKERS": str(NWORKERS), "SERVERS": str(NSERVERS)},
    check=True,
)

# Bring up containers
subprocess.run(
    ["docker", "compose", "-f", COMPOSE_FILE, "up", "--build", "-d", "--remove-orphans"],
    check=True,
)

time.sleep(3)
print("All entities running.")
# Out:
# [sudo] contraseña para lminervino18:
# #1 [internal] load local bake definitions
# #1 reading from stdin 2.21kB done
# #1 DONE 0.0s
#
# #2 [server-1 internal] load build definition from Dockerfile
# #2 DONE 0.0s
#
# #3 [worker-2 internal] load build definition from Dockerfile
# #3 transferring dockerfile: 1.03kB done
# #3 DONE 0.0s
#
# #2 [server-1 internal] load build definition from Dockerfile
# #2 transferring dockerfile: 982B done
# #2 DONE 0.0s
#
# #4 [worker-2 internal] load metadata for docker.io/library/debian:bookworm-slim
# #4 ...
#
# #5 [worker-2 internal] load metadata for docker.io/library/rust:1.92
# #5 DONE 0.9s
#
# #4 [worker-2 internal] load metadata for docker.io/library/debian:bookworm-slim
# #4 DONE 1.2s
#
# #6 [worker-0 internal] load .dockerignore
# #6 transferring context: 172B done
# #6 DONE 0.0s
#
# #7 [server-1 stage-3 1/2] FROM docker.io/library/debian:bookworm-slim@sha256:f06537653ac770703bc45b4b113475bd402f451e85223f0f2837acbf89ab020a
# #7 DONE 0.0s
#
# #8 [server-1 chef 1/3] FROM docker.io/library/rust:1.92@sha256:f58923369ba295ae1f60bc49d03f2c955a5c93a0b7d49acfb2b2a65bebaf350d
# #8 DONE 0.0s
#
# #9 [worker-1 internal] load build context
# #9 transferring context: 149.06kB 0.0s done
# #9 DONE 0.0s
#
# #10 [worker-0 builder 2/8] RUN if [ "release" = "release" ]; then export FLAG="--release"; fi &&   cargo chef cook $FLAG --recipe-path recipe.json
# #10 CACHED
#
# #11 [worker-2 builder 3/8] COPY Cargo.* .
# #11 CACHED
#
# #12 [worker-0 chef 2/3] RUN cargo install cargo-chef
# #12 CACHED
#
# #13 [worker-0 chef 3/3] WORKDIR /app
# #13 CACHED
#
# #14 [worker-0 planner 1/2] COPY . .
# #14 CACHED
#
# #15 [worker-2 planner 2/2] RUN cargo chef prepare --recipe-path recipe.json
# #15 CACHED
#
# #16 [server-0 builder 1/7] COPY --from=planner /app/recipe.json recipe.json
# #16 CACHED
#
# #17 [worker-2 builder 4/8] COPY worker    ./worker
# #17 DONE 0.1s
#
# #18 [worker-0 builder 5/8] COPY comms            ./comms
# #18 DONE 0.0s
#
# #19 [worker-0 builder 6/8] COPY machine_learning ./machine_learning
# #19 DONE 0.2s
#
# #20 [worker-1 builder 7/8] RUN if [ "release" = "release" ]; then export FLAG="--release"; fi &&   cargo build $FLAG --bin worker
# #20 0.173 warning: /app/orchestra-py/Cargo.toml: `edition` is set on library `_orchestra` which is deprecated
# #20 0.173 warning: /app/orchestrator/Cargo.toml: `edition` is set on library `orchestrator` which is deprecated
# #20 0.173 warning: /app/orchestrator/Cargo.toml: `edition` is set on binary `orchestrator` which is deprecated
# #20 0.173 warning: /app/parameter_server/Cargo.toml: `edition` is set on binary `parameter_server` which is deprecated
# #20 0.173 warning: /app/orchestui/Cargo.toml: `edition` is set on binary `orchestui` which is deprecated
# #20 0.526    Compiling comms v0.1.0 (/app/comms)
# #20 1.313    Compiling machine_learning v0.1.0 (/app/machine_learning)
# #20 1.761    Compiling worker v0.1.0 (/app/worker)
# #20 5.125     Finished `release` profile [optimized] target(s) in 4.96s
# #20 DONE 5.2s
#
# #21 [worker-2 builder 8/8] RUN mv target/release/worker /app/binary
# #21 DONE 0.5s
#
# #22 [server-0 builder 2/7] RUN if [ "release" = "release" ]; then export FLAG="--release"; fi &&   cargo chef cook $FLAG --recipe-path recipe.json
# #22 0.403 warning: /app/parameter_server/Cargo.toml: `edition` is set on binary `parameter_server` which is deprecated
# #22 0.403 warning: /app/comms/Cargo.toml: `edition` is set on library `comms` which is deprecated
# #22 0.403 warning: /app/comms/Cargo.toml: `edition` is set on test `integration` which is deprecated
# #22 0.403 warning: /app/orchestrator/Cargo.toml: `edition` is set on library `orchestrator` which is deprecated
# #22 0.403 warning: /app/orchestrator/Cargo.toml: `edition` is set on binary `orchestrator` which is deprecated
# #22 0.403 warning: /app/orchestra-py/Cargo.toml: `edition` is set on library `_orchestra` which is deprecated
# #22 0.403 warning: /app/worker/Cargo.toml: `edition` is set on library `worker` which is deprecated
# #22 0.403 warning: /app/worker/Cargo.toml: `edition` is set on binary `worker` which is deprecated
# #22 0.403 warning: /app/worker/Cargo.toml: `edition` is set on test `worker_protocol` which is deprecated
# #22 0.403 warning: /app/machine_learning/Cargo.toml: `edition` is set on library `machine_learning` which is deprecated
# #22 0.403 warning: /app/orchestui/Cargo.toml: `edition` is set on binary `orchestui` which is deprecated
# #22 0.545     Updating crates.io index
# #22 3.453  Downloading crates ...
# #22 3.644   Downloaded allocator-api2 v0.2.21
# #22 3.655   Downloaded anstyle v1.0.13
# #22 3.687   Downloaded bytemuck v1.25.0
# #22 3.695   Downloaded futures-io v0.3.32
# #22 3.696   Downloaded env_filter v0.1.4
# #22 3.707   Downloaded futures-macro v0.3.32
# #22 3.715   Downloaded futures-sink v0.3.32
# #22 3.716   Downloaded castaway v0.2.4
# #22 3.726   Downloaded futures-core v0.3.32
# #22 3.729   Downloaded colorchoice v1.0.4
# #22 3.731   Downloaded bytemuck_derive v1.10.2
# #22 3.733   Downloaded cassowary v0.3.0
# #22 3.742   Downloaded memoffset v0.9.1
# #22 3.757   Downloaded ndarray-rand v0.16.0
# #22 3.768   Downloaded lru v0.12.5
# #22 3.771   Downloaded scopeguard v1.2.0
# #22 3.773   Downloaded pyo3-macros v0.22.6
# #22 3.774   Downloaded is-docker v0.2.0
# #22 3.787   Downloaded trait-variant v0.1.2
# #22 3.789   Downloaded is-wsl v0.4.0
# #22 3.792   Downloaded rawpointer v0.2.1
# #22 3.801   Downloaded unindent v0.2.4
# #22 3.803   Downloaded signal-hook-mio v0.2.5
# #22 3.806   Downloaded unicode-truncate v1.1.0
# #22 3.810   Downloaded futures-task v0.3.32
# #22 3.812   Downloaded futures-executor v0.3.32
# #22 3.815   Downloaded stability v0.2.1
# #22 3.817   Downloaded async-trait v0.1.89
# #22 3.822   Downloaded env_logger v0.11.8
# #22 3.826   Downloaded strum v0.26.3
# #22 3.842   Downloaded ppv-lite86 v0.2.21
# #22 3.846   Downloaded rand_chacha v0.9.0
# #22 3.847   Downloaded pyo3-build-config v0.22.6
# #22 3.850   Downloaded num-integer v0.1.46
# #22 3.853   Downloaded pin-project-lite v0.2.16
# #22 3.863   Downloaded zmij v1.0.12
# #22 3.865   Downloaded slab v0.4.12
# #22 3.868   Downloaded signal-hook-registry v1.4.7
# #22 3.871   Downloaded safetensors v0.4.5
# #22 3.873   Downloaded paste v1.0.15
# #22 3.878   Downloaded strum_macros v0.26.4
# #22 3.882   Downloaded target-lexicon v0.12.16
# #22 3.886   Downloaded num-complex v0.4.6
# #22 3.890   Downloaded futures-channel v0.3.32
# #22 3.893   Downloaded bitflags v2.10.0
# #22 3.900   Downloaded unicode-ident v1.0.22
# #22 3.915   Downloaded parking_lot_core v0.9.12
# #22 3.915   Downloaded proc-macro2 v1.0.103
# #22 3.915   Downloaded num-traits v0.2.19
# #22 3.919   Downloaded matrixmultiply v0.3.10
# #22 3.925   Downloaded tokio-macros v2.6.0
# #22 3.927   Downloaded half v2.3.1
# #22 3.932   Downloaded pyo3-macros-backend v0.22.6
# #22 3.937   Downloaded pyo3-ffi v0.22.6
# #22 3.945   Downloaded rayon-core v1.13.0
# #22 3.955   Downloaded rand_distr v0.5.1
# #22 3.960   Downloaded rand v0.9.2
# #22 3.967   Downloaded unicode-segmentation v1.12.0
# #22 3.977   Downloaded mio v1.1.1
# #22 3.983   Downloaded crossterm v0.27.0
# #22 3.991   Downloaded mio v0.8.11
# #22 3.999   Downloaded regex v1.12.2
# #22 4.024   Downloaded rayon v1.11.0
# #22 4.051   Downloaded futures-util v0.3.32
# #22 4.067   Downloaded libm v0.2.15
# #22 4.082   Downloaded ndarray v0.17.2
# #22 4.094   Downloaded unicode-width v0.1.14
# #22 4.101   Downloaded zerocopy v0.8.27
# #22 4.160   Downloaded syn v2.0.111
# #22 4.173   Downloaded itertools v0.13.0
# #22 4.182   Downloaded itertools v0.12.1
# #22 4.190   Downloaded memchr v2.7.6
# #22 4.201   Downloaded regex-syntax v0.8.8
# #22 4.209   Downloaded bytes v1.11.0
# #22 4.215   Downloaded socket2 v0.6.1
# #22 4.218   Downloaded signal-hook v0.3.18
# #22 4.222   Downloaded ryu v1.0.22
# #22 4.226   Downloaded compact_str v0.7.1
# #22 4.229   Downloaded ratatui v0.26.3
# #22 4.250   Downloaded futures v0.3.32
# #22 4.257   Downloaded quote v1.0.42
# #22 4.262   Downloaded open v5.3.3
# #22 4.266   Downloaded pyo3 v0.22.6
# #22 4.293   Downloaded once_cell v1.21.3
# #22 4.297   Downloaded anyhow v1.0.100
# #22 4.303   Downloaded regex-automata v0.4.13
# #22 4.325   Downloaded rand_core v0.9.3
# #22 4.327   Downloaded parking_lot v0.12.5
# #22 4.330   Downloaded rustversion v1.0.22
# #22 4.333   Downloaded indoc v2.0.7
# #22 4.337   Downloaded lock_api v0.4.14
# #22 4.338   Downloaded jiff v0.2.18
# #22 4.353   Downloaded libc v0.2.178
# #22 4.381   Downloaded tokio v1.49.0
# #22 4.472    Compiling proc-macro2 v1.0.103
# #22 4.472    Compiling unicode-ident v1.0.22
# #22 4.472    Compiling quote v1.0.42
# #22 4.472    Compiling libc v0.2.178
# #22 4.472    Compiling cfg-if v1.0.4
# #22 4.472    Compiling autocfg v1.5.0
# #22 4.473    Compiling memchr v2.7.6
# #22 4.475    Compiling target-lexicon v0.12.16
# #22 4.618    Compiling parking_lot_core v0.9.12
# #22 4.699    Compiling serde_core v1.0.228
# #22 4.915    Compiling scopeguard v1.2.0
# #22 4.952    Compiling smallvec v1.15.1
# #22 5.053    Compiling lock_api v0.4.14
# #22 5.067    Compiling itoa v1.0.17
# #22 5.196    Compiling log v0.4.29
# #22 5.412    Compiling pin-project-lite v0.2.16
# #22 5.425    Compiling zmij v1.0.12
# #22 5.612    Compiling once_cell v1.21.3
# #22 5.796    Compiling pyo3-build-config v0.22.6
# #22 5.879    Compiling serde_json v1.0.149
# #22 6.073    Compiling libm v0.2.15
# #22 6.146    Compiling serde v1.0.228
# #22 ...
#
# #7 [worker-1 stage-3 1/2] FROM docker.io/library/debian:bookworm-slim@sha256:f06537653ac770703bc45b4b113475bd402f451e85223f0f2837acbf89ab020a
# #7 CACHED
#
# #23 [worker-1 stage-3 2/2] COPY --from=builder /app/binary /usr/local/bin
# #23 DONE 0.1s
#
# #24 [worker-1] exporting to image
# #24 exporting layers 0.0s done
# #24 writing image sha256:661c3bc807bcdc99e9e7882ea4b02d999f675a2fe05ee19f2bb7c1aaa2c08352 done
# #24 naming to docker.io/library/distributed-training-worker-1 0.0s done
# #24 DONE 0.1s
#
# #25 [worker-2] exporting to image
# #25 exporting layers 0.0s done
# #25 writing image sha256:661c3bc807bcdc99e9e7882ea4b02d999f675a2fe05ee19f2bb7c1aaa2c08352 done
# #25 naming to docker.io/library/distributed-training-worker-2 0.0s done
# #25 DONE 0.1s
#
# #26 [worker-0] exporting to image
# #26 exporting layers 0.0s done
# #26 writing image sha256:661c3bc807bcdc99e9e7882ea4b02d999f675a2fe05ee19f2bb7c1aaa2c08352 done
# #26 naming to docker.io/library/distributed-training-worker-0 done
# #26 DONE 0.1s
#
# #27 [worker-0] resolving provenance for metadata file
# #27 DONE 0.1s
#
# #28 [worker-2] resolving provenance for metadata file
# #28 DONE 0.0s
#
# #29 [worker-1] resolving provenance for metadata file
# #29 DONE 0.1s
#
# #22 [server-0 builder 2/7] RUN if [ "release" = "release" ]; then export FLAG="--release"; fi &&   cargo chef cook $FLAG --recipe-path recipe.json
# #22 6.618    Compiling syn v2.0.111
# #22 6.655    Compiling either v1.15.0
# #22 6.695    Compiling crossbeam-utils v0.8.21
# #22 7.064    Compiling aho-corasick v1.1.4
# #22 7.079    Compiling num-traits v0.2.19
# #22 7.156    Compiling signal-hook-registry v1.4.7
# #22 7.319    Compiling futures-sink v0.3.32
# #22 7.397    Compiling futures-core v0.3.32
# #22 7.409    Compiling getrandom v0.3.4
# #22 7.552    Compiling parking_lot v0.12.5
# #22 7.660    Compiling zerocopy v0.8.27
# #22 7.788    Compiling regex-syntax v0.8.8
# #22 8.414    Compiling futures-channel v0.3.32
# #22 8.805    Compiling mio v1.1.1
# #22 8.848    Compiling socket2 v0.6.1
# #22 10.01    Compiling regex-automata v0.4.13
# #22 10.03    Compiling futures-io v0.3.32
# #22 10.24    Compiling utf8parse v0.2.2
# #22 10.35    Compiling bytes v1.11.0
# #22 10.41    Compiling futures-task v0.3.32
# #22 10.66    Compiling slab v0.4.12
# #22 10.98    Compiling anstyle-parse v0.2.7
# #22 12.02    Compiling crossbeam-epoch v0.9.18
# #22 12.99    Compiling colorchoice v1.0.4
# #22 13.06    Compiling is_terminal_polyfill v1.70.2
# #22 13.14    Compiling anstyle-query v1.1.5
# #22 13.19    Compiling rayon-core v1.13.0
# #22 13.28    Compiling anstyle v1.0.13
# #22 13.72    Compiling anstream v0.6.21
# #22 13.79    Compiling rand_core v0.9.3
# #22 14.17    Compiling crossbeam-deque v0.8.6
# #22 14.41    Compiling jiff v0.2.18
# #22 14.41    Compiling rustversion v1.0.22
# #22 14.48    Compiling regex v1.12.2
# #22 14.64    Compiling serde_derive v1.0.228
# #22 14.76    Compiling bytemuck_derive v1.10.2
# #22 15.90    Compiling tokio-macros v2.6.0
# #22 16.28    Compiling bytemuck v1.25.0
# #22 16.52    Compiling futures-macro v0.3.32
# #22 16.60    Compiling half v2.3.1
# #22 16.69    Compiling tokio v1.49.0
# #22 16.87    Compiling ppv-lite86 v0.2.21
# #22 17.51    Compiling env_filter v0.1.4
# #22 17.59    Compiling heck v0.5.0
# #22 17.62    Compiling futures-util v0.3.32
# #22 17.84    Compiling rand_chacha v0.9.0
# #22 18.52    Compiling matrixmultiply v0.3.10
# #22 18.85    Compiling rand v0.9.2
# #22 19.28    Compiling rayon v1.11.0
# #22 19.79    Compiling rawpointer v0.2.1
# #22 20.04    Compiling signal-hook v0.3.18
# #22 20.24    Compiling rand_distr v0.5.1
# #22 20.81    Compiling num-integer v0.1.46
# #22 21.42    Compiling env_logger v0.11.8
# #22 21.52    Compiling num-complex v0.4.6
# #22 22.18    Compiling futures-executor v0.3.32
# #22 22.32    Compiling pyo3-macros-backend v0.22.6
# #22 22.98    Compiling futures v0.3.32
# #22 23.16    Compiling pyo3-ffi v0.22.6
# #22 23.53    Compiling safetensors v0.4.5
# #22 23.65    Compiling mio v0.8.11
# #22 24.11    Compiling ndarray v0.17.2
# #22 24.35    Compiling memoffset v0.9.1
# #22 24.48    Compiling paste v1.0.15
# #22 24.66    Compiling allocator-api2 v0.2.21
# #22 25.00    Compiling equivalent v1.0.2
# #22 25.09    Compiling foldhash v0.1.5
# #22 25.25    Compiling hashbrown v0.15.5
# #22 25.41    Compiling signal-hook-mio v0.2.5
# #22 26.07    Compiling comms v0.0.1 (/app/comms)
# #22 26.14    Compiling orchestrator v0.0.1 (/app/orchestrator)
# #22 26.18    Compiling is-docker v0.2.0
# #22 26.25    Compiling strum_macros v0.26.4
# #22 26.42    Compiling castaway v0.2.4
# #22 26.52    Compiling pyo3 v0.22.6
# #22 26.75    Compiling itertools v0.13.0
# #22 26.81    Compiling unicode-width v0.1.14
# #22 27.16    Compiling bitflags v2.10.0
# #22 27.56    Compiling static_assertions v1.1.0
# #22 27.63    Compiling ryu v1.0.22
# #22 28.10    Compiling anyhow v1.0.100
# #22 29.10    Compiling unicode-segmentation v1.12.0
# #22 29.32    Compiling strum v0.26.3
# #22 29.53    Compiling compact_str v0.7.1
# #22 29.53    Compiling crossterm v0.27.0
# #22 30.21    Compiling unicode-truncate v1.1.0
# #22 30.54    Compiling is-wsl v0.4.0
# #22 30.56    Compiling lru v0.12.5
# #22 31.00    Compiling stability v0.2.1
# #22 31.79    Compiling itertools v0.12.1
# #22 31.83    Compiling cassowary v0.3.0
# #22 31.86    Compiling pathdiff v0.2.3
# #22 32.01    Compiling unindent v0.2.4
# #22 32.52    Compiling pyo3-macros v0.22.6
# #22 32.55    Compiling indoc v2.0.7
# #22 33.28    Compiling open v5.3.3
# #22 33.65    Compiling async-trait v0.1.89
# #22 34.18    Compiling trait-variant v0.1.2
# #22 35.09    Compiling ndarray-rand v0.16.0
# #22 35.55    Compiling machine_learning v0.0.1 (/app/machine_learning)
# #22 35.57    Compiling ratatui v0.26.3
# #22 35.66    Compiling worker v0.0.1 (/app/worker)
# #22 36.88    Compiling parameter_server v0.0.1 (/app/parameter_server)
# #22 39.01    Compiling orchestra-py v0.0.1 (/app/orchestra-py)
# #22 40.25    Compiling orchestui v0.0.1 (/app/orchestui)
# #22 40.32     Finished `release` profile [optimized] target(s) in 39.93s
# #22 DONE 40.7s
#
# #30 [server-1 builder 3/7] COPY Cargo.* .
# #30 DONE 0.1s
#
# #31 [server-1 builder 4/7] COPY parameter_server    ./parameter_server
# #31 DONE 0.1s
#
# #32 [server-1 builder 5/7] COPY comms ./comms
# #32 DONE 0.0s
#
# #33 [server-0 builder 6/7] RUN if [ "release" = "release" ]; then export FLAG="--release"; fi &&   cargo build $FLAG --bin parameter_server
# #33 0.249 warning: /app/orchestrator/Cargo.toml: `edition` is set on library `orchestrator` which is deprecated
# #33 0.249 warning: /app/orchestrator/Cargo.toml: `edition` is set on binary `orchestrator` which is deprecated
# #33 0.249 warning: /app/worker/Cargo.toml: `edition` is set on library `worker` which is deprecated
# #33 0.249 warning: /app/worker/Cargo.toml: `edition` is set on binary `worker` which is deprecated
# #33 0.249 warning: /app/worker/Cargo.toml: `edition` is set on test `worker_protocol` which is deprecated
# #33 0.249 warning: /app/orchestra-py/Cargo.toml: `edition` is set on library `_orchestra` which is deprecated
# #33 0.249 warning: /app/machine_learning/Cargo.toml: `edition` is set on library `machine_learning` which is deprecated
# #33 0.249 warning: /app/orchestui/Cargo.toml: `edition` is set on binary `orchestui` which is deprecated
# #33 0.444    Compiling comms v0.1.0 (/app/comms)
# #33 0.988    Compiling parameter_server v0.1.0 (/app/parameter_server)
# #33 5.640     Finished `release` profile [optimized] target(s) in 5.41s
# #33 DONE 5.7s
#
# #34 [server-1 builder 7/7] RUN mv target/release/parameter_server /app/binary
# #34 DONE 0.2s
#
# #35 [server-0 stage-3 2/2] COPY --from=builder /app/binary /usr/local/bin
# #35 DONE 0.0s
#
# #36 [server-1] exporting to image
# #36 exporting layers 0.0s done
# #36 writing image sha256:782755d0c4055fb6844fb36c8792af895ca08b2c174ea0787c1d7bcdae15cd11 done
# #36 naming to docker.io/library/distributed-training-server-1 done
# #36 DONE 0.0s
#
# #37 [server-0] exporting to image
# #37 exporting layers 0.0s done
# #37 writing image sha256:782755d0c4055fb6844fb36c8792af895ca08b2c174ea0787c1d7bcdae15cd11 done
# #37 naming to docker.io/library/distributed-training-server-0 done
# #37 DONE 0.0s
#
# #38 [server-1] resolving provenance for metadata file
# #38 DONE 0.0s
#
# #39 [server-0] resolving provenance for metadata file
# #39 DONE 0.0s
#  server-1  Built
#  worker-2  Built
#  worker-0  Built
#  worker-1  Built
#  server-0  Built
#  Network distributed-training_training-network  Creating
#  Network distributed-training_training-network  Created
#  Container server-0  Creating
#  Container server-1  Creating
#  Container server-0  Created
#  Container server-1  Created
#  Container worker-1  Creating
#  Container worker-2  Creating
#  Container worker-0  Creating
#  Container worker-2  Created
#  Container worker-1  Created
#  Container worker-0  Created
#  Container server-1  Starting
#  Container server-0  Starting
#  Container server-0  Started
#  Container server-1  Started
#  Container worker-2  Starting
#  Container worker-0  Starting
#  Container worker-1  Starting
#  Container worker-0  Started
#  Container worker-1  Started
#  Container worker-2  Started
# All entities running.

# %% [markdown]
# ## 3. Model Architecture
#
# Defines the model architecture used for both distributed training (cell 3) and accuracy evaluation (cell 4). Each layer specifies an output size and an optional activation function. Supported activations: `"sigmoid"`, `None`.

# %%
INPUT_SIZE = 784

ARCHITECTURE = [
    {"size": 128, "act": "sigmoid"},
    {"size": 64,  "act": "sigmoid"},
    {"size": 10,  "act": None},
]

# %%
import sys
# !{sys.executable} -m pip install maturin
import subprocess
subprocess.run([sys.executable, "-m", "maturin", "develop"], cwd="orchestra-py")
# Out:
# error: externally-managed-environment
#
# × This environment is externally managed
# ╰─> To install Python packages system-wide, try apt install
#     python3-xyz, where xyz is the package you are trying to
#     install.
#
#     If you wish to install a non-Debian-packaged Python package,
#     create a virtual environment using python3 -m venv path/to/venv.
#     Then use path/to/venv/bin/python and path/to/venv/bin/pip. Make
#     sure you have python3-full installed.
#
#     If you wish to install a non-Debian packaged Python application,
#     it may be easiest to use pipx install xyz, which will manage a
#     virtual environment for you. Make sure you have pipx installed.
#
#     See /usr/share/doc/python3.12/README.venv for more information.
#
# note: If you believe this is a mistake, please contact your Python installation or OS distribution provider. You can override this, at the risk of breaking your Python installation or OS, by passing --break-system-packages.
# hint: See PEP 668 for the detailed specification.
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 4
#       2 get_ipython().system('{sys.executable} -m pip install maturin')
#       3 import subprocess
# ----> 4 subprocess.run([sys.executable, "-m", "maturin", "develop"], cwd="orchestra-py")
#
# File /usr/lib/python3.12/subprocess.py:548, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     545     kwargs['stdout'] = PIPE
#     546     kwargs['stderr'] = PIPE
# --> 548 with Popen(*popenargs, **kwargs) as process:
#     549     try:
#     550         stdout, stderr = process.communicate(input, timeout=timeout)
#
# File /usr/lib/python3.12/subprocess.py:1026, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize, process_group)
#    1022         if self.text_mode:
#    1023             self.stderr = io.TextIOWrapper(self.stderr,
#    1024                     encoding=encoding, errors=errors)
# -> 1026     self._execute_child(args, executable, preexec_fn, close_fds,
#    1027                         pass_fds, cwd, env,
#    1028                         startupinfo, creationflags, shell,
#    1029                         p2cread, p2cwrite,
#    1030                         c2pread, c2pwrite,
#    1031                         errread, errwrite,
#    1032                         restore_signals,
#    1033                         gid, gids, uid, umask,
#    1034                         start_new_session, process_group)
#    1035 except:
#    1036     # Cleanup if the child failed starting.
#    1037     for f in filter(None, (self.stdin, self.stdout, self.stderr)):
#
# File /usr/lib/python3.12/subprocess.py:1955, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, gid, gids, uid, umask, start_new_session, process_group)
#    1953     err_msg = os.strerror(errno_num)
#    1954 if err_filename is not None:
# -> 1955     raise child_exception_type(errno_num, err_msg, err_filename)
#    1956 else:
#    1957     raise child_exception_type(errno_num, err_msg)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'orchestra-py'

# %% [markdown]
# ## 4. Distributed Training with O.N.O
#
# Builds a dense network from `ARCHITECTURE` with Kaiming initialization, then trains it distributedly using the Parameter Server algorithm (`NonBlockingSync`, `WildStore`, batch size 128, 300 epochs). Once complete, the trained weights are saved to `data/mnist_model.safetensors`.

# %%
import orchestra
from orchestra import Sequential, orchestrate
from orchestra.arch import Dense
from orchestra.activations import Sigmoid
from orchestra.initialization import Kaiming
from orchestra.datasets import LocalDataset
from orchestra.optimizers import GradientDescent
from orchestra.sync import NonBlockingSync
from orchestra.store import WildStore
import subprocess
import threading

ACT_MAP = {
    "sigmoid": Sigmoid(),
    None: None,
}

model = Sequential([
    Dense(layer["size"], Kaiming(), ACT_MAP[layer["act"]])
    for layer in ARCHITECTURE
])

training = orchestra.parameter_server(
    worker_addrs=WORKER_ADDRS,
    server_addrs=SERVER_ADDRS,
    dataset=LocalDataset(TRAIN_BIN, x_size=INPUT_SIZE, y_size=Y_SIZE),
    optimizer=GradientDescent(lr=0.1),
    sync=NonBlockingSync(),
    store=WildStore(),
    max_epochs=50,
    batch_size=256,
    offline_epochs=0,
    seed=42,
)

print("Starting training session...")
session = orchestrate(model, training)
trained = session.wait()
print(f"Training complete — {len(trained.weights())} parameters")

trained.save_safetensors(SAFETENSORS_PATH)
size = os.path.getsize(SAFETENSORS_PATH)
assert size > 0
print(f"Model saved to {SAFETENSORS_PATH} ({size} bytes)")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 import orchestra
#       2 from orchestra import Sequential, orchestrate
#       3 from orchestra.arch import Dense
#
# ModuleNotFoundError: No module named 'orchestra'

# %% [markdown]
# ## 5. Accuracy Evaluation with PyTorch
#
# Loads the saved `.safetensors` file into an equivalent PyTorch model built dynamically from `ARCHITECTURE`. O.N.O stores weight matrices as `[input, output]` so they are transposed before loading into PyTorch's `Linear` layers (which expect `[output, input]`). The full 10,000-sample MNIST test set is then evaluated and top-1 accuracy is printed.

# %%
import torch
import torch.nn as nn
from safetensors.torch import load_file

ACT_FN_MAP = {
    "sigmoid": torch.sigmoid,
    None: None,
}

class OnoNet(nn.Module):
    def __init__(self, input_size, architecture):
        super().__init__()
        sizes = [input_size] + [l["size"] for l in architecture]
        self.linears = nn.ModuleList([
            nn.Linear(sizes[i], sizes[i+1])
            for i in range(len(architecture))
        ])
        self.acts = [ACT_FN_MAP[l["act"]] for l in architecture]

    def forward(self, x):
        for linear, act in zip(self.linears, self.acts):
            x = linear(x)
            if act is not None:
                x = act(x)
        return x

state_dict = load_file(SAFETENSORS_PATH)
print("Loaded tensors:", list(state_dict.keys()))

net = OnoNet(INPUT_SIZE, ARCHITECTURE)

with torch.no_grad():
    for i, linear in enumerate(net.linears):
        linear.weight.copy_(state_dict[f"layer_{i}.weight"].T)
        linear.bias.copy_(state_dict[f"layer_{i}.bias"])

net.eval()

raw = np.fromfile(TEST_BIN, dtype=np.float32).reshape(-1, ROW_SIZE)
x_test = torch.tensor(raw[:, :INPUT_SIZE])
y_test = torch.tensor(raw[:, INPUT_SIZE:].argmax(axis=1), dtype=torch.long)

with torch.no_grad():
    preds = net(x_test).argmax(dim=1)
    acc = (preds == y_test).float().mean().item() * 100

print(f"\nTest accuracy: {acc:.2f}%")
# Out:
# Loaded tensors: ['layer_0.bias', 'layer_0.weight', 'layer_1.bias', 'layer_1.weight', 'layer_2.bias', 'layer_2.weight']
#
# Test accuracy: 23.28%

# %% [markdown]
# ## 6. Stop Workers & Servers
#
# Terminates all worker and server subprocesses started in step 2 and closes their log file handles.

# %%
print("Stopping all entities...")
subprocess.run(
    ["docker", "compose", "-f", COMPOSE_FILE, "down"],
    check=True,
)
print("Done.")
# Out:
# Stopping all entities...
#  Container worker-1  Stopping
#  Container worker-0  Stopping
#  Container worker-2  Stopping
#  Container worker-1  Stopped
#  Container worker-1  Removing
#  Container worker-1  Removed
#  Container worker-0  Stopped
#  Container worker-0  Removing
#  Container worker-0  Removed
#  Container worker-2  Stopped
#  Container worker-2  Removing
#  Container worker-2  Removed
#  Container server-0  Stopping
#  Container server-1  Stopping
